# %% [markdown]
# ## 二叉树

# %% [markdown]
# 二叉树(binary tree)大致如下所示：
#
# ![image.png](attachment:bf54777e-b573-4a76-9702-35d2b7e898f3.png)

# %% [markdown]
# 代码的结构如下所示：

# %%
{
    "value": 4,
    "left": {
        "value": 3,
        "left": None,
        "right": None
    },
    "right":{
        "value": 23,
        "left": None,
        "right": None
    }
}
# Out:
# {'value': 4,
#  'left': {'value': 3, 'left': None, 'right': None},
#  'right': {'value': 23, 'left': None, 'right': None}}

# %% [markdown]
# ## 一些术语

# %% [markdown]
# 这是一个完全（full）二叉树：
#
# ![image.png](attachment:dca42752-a2de-45d1-ae5c-44a15866e84b.png)
#
# 但是这不是一个完全二叉树：
#
# ![image.png](attachment:3491dc34-f5d2-4a98-81c0-5050cf01a7d1.png)
#
# 而这则是一个完美完全二叉树（perfect full binary tree）:
#
# ![image.png](attachment:4bcc6b21-3126-44f1-a79c-835b68c12cae.png)
#
# 判断一个完全二叉树是否是perfect的标准是查看树中觉有任何结点的任何级别是否被完全的填满。
#
# 一颗完整的数字，从左到右填充树是没有任何间隙的，这样的树是complete的：
#
# ![image.png](attachment:269d9375-6595-421f-ab0a-68cb3ca4eac0.png)
#
# 这棵树则不是complete的：
#
# ![image.png](attachment:ec57cd61-b6ce-4fa5-9205-6730d405a2c6.png)

# %% [markdown]
# ## 各个结点

# %% [markdown]
# Parent Node：
#
# ![image.png](attachment:e8244dfc-06e2-493f-abd1-25f4c78da864.png)
#
# Children Node：
#
# ![image.png](attachment:58b18841-32f3-496e-9d36-f9a5af3bcc06.png)

# %% [markdown]
# 每一个结点都只能够有一个父结点，如果有多个则不是tree：
#
# ![image.png](attachment:095bb0d7-11ce-461c-8003-d512f383c68e.png)

# %% [markdown]
# 最底层的结点没有子结点，这些结点则被称之为叫做leaf：
#
# ![image.png](attachment:6ca433ec-5d6c-4ad3-927e-154977553d18.png)

# %% [markdown]
# ## Binrary Search Trees

# %% [markdown]
# 前面的树是二叉树，但是不是二插搜索树。

# %% [markdown]
# 我们看一下这样的一个例子。
#
# 假设树中有一个结点作为root node：
#
# ![image.png](attachment:0cafe77a-6f11-4d43-b263-0b5cf70eeada.png)
#
# 如果有结点大于了这个结点，则在这个结点的右边；反之，则是左边。
#
# ![image.png](attachment:9a83d279-062d-480f-9284-8dfe17ddd8ce.png)
#
# 假设我们出现了第三个结点，结点的值是52,那么我们：首先将这个结点和root node进行比较，然后判断这个结点归到root node哪一边：
#
# ![image.png](attachment:61dec82c-bb23-483a-9bd7-aaa9bd5a9f7e.png)
#
# 然而我们考察一下21：
#
# ![image.png](attachment:545732bc-3232-4859-892e-706aa9c22ab8.png)
#
# 同理，对于值为82的结点：
#
# ![image.png](attachment:93019273-8b87-4ab8-ad8a-012d60b75726.png)
#
# 对于值为18的结点：
#
# ![image.png](attachment:499506fa-42d1-4dd4-a204-1dc1f97362b2.png)
#
# 值为27的结点：
#
# ![image.png](attachment:c0adb406-200a-46a0-8b82-61946dc1096c.png)

# %% [markdown]
# 可以发现：
#
# 所有大于47的结点都在右边
#
# ![image.png](attachment:2f7f149c-11ce-4265-8eca-715659a87f05.png)
#
# 而所有小于47的结点都在左边
#
# ![image.png](attachment:13df25bd-6ff4-4815-9d26-8b5bd452cde2.png)
