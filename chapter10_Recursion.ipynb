# %% [markdown]
# ## 什么是 Recursion

# %% [markdown]
# 一句话：递归是一个函数调用其自身。
#
# 例子：
#
# ![image.png](attachment:8edd94ad-414e-4548-9d99-919ded3f1913.png)
#
# 为代码如下所示：
#
# ![image.png](attachment:8d320d49-b161-4316-81e2-a730cb2ea214.png)

# %% [markdown]
# ## Call Stack

# %% [markdown]
# ![image.png](attachment:82eb91d6-61ef-4c7e-9212-b50f1784b970.png)
#
# 我们修改一下代码：
#
# ![image.png](attachment:682226cc-e4a5-468b-b094-e3c3f49dfd77.png)
#
# 使用VSCODE提供的断点功能：
#
# ![image.png](attachment:43ceefbb-0e46-43bf-b658-b0bd948dd9b3.png)

# %% [markdown]
# ## 使用递归来实现Factorial函数

# %%
def factorial(n):
    if n == 0:
        # Base case n = 0
        return 1
    else:
        # Use the definition of factorial function
        return n * factorial(n-1)

# %%
print(factorial(5))
# Out:
# 120
